# %% [markdown]
# <a href="https://colab.research.google.com/github/chahatpatel2003/164/blob/main/CSCI_164_photo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
# !pip install transformers
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
#car
#link - https://drive.google.com/file/d/1NIWxO_Wy0vH89g4KdEUzJBg7oXv-DpTH/view?usp=share_link
# !gdown 1NIWxO_Wy0vH89g4KdEUzJBg7oXv-DpTH
pic_1 = "Screenshot 2025-01-28 at 8.04.18 PM.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NIWxO_Wy0vH89g4KdEUzJBg7oXv-DpTH
# To: /content/Screenshot 2025-01-28 at 8.04.18 PM.png
# 100% 151k/151k [00:00<00:00, 51.4MB/s]

# %%
#speaker
# link - https://drive.google.com/file/d/1Cc_aFgLcdZO14gnNYJ9V5YBAiv6bE4TO/view?usp=share_link
# !gdown 1Cc_aFgLcdZO14gnNYJ9V5YBAiv6bE4TO
pic_2 = "Screenshot 2025-01-28 at 8.40.29 PM.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Cc_aFgLcdZO14gnNYJ9V5YBAiv6bE4TO
# To: /content/Screenshot 2025-01-28 at 8.40.29 PM.png
# 100% 60.1k/60.1k [00:00<00:00, 6.81MB/s]

# %%
#effiel tower
#file link - https://drive.google.com/file/d/134YYsRkkV7wj-OIDKLe8pljmmBamviVN/view?usp=share_link
# !gdown 134YYsRkkV7wj-OIDKLe8pljmmBamviVN
pic_3 = "Screenshot 2025-01-28 at 8.04.41 PM.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=134YYsRkkV7wj-OIDKLe8pljmmBamviVN
# To: /content/Screenshot 2025-01-28 at 8.04.41 PM.png
# 100% 543k/543k [00:00<00:00, 7.08MB/s]

# %%
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")

# %%
file_name = pic_1

# %%
captioner1 = pipeline("image-to-text", model="Salesforce/blip2-opt-2.7b")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")

# %%
captioner3 = pipeline("image-to-text", model="Salesforce/blip2-opt-2.7b")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pic = pic_1
pic2 = pic_2
pic3 = pic_3

# %%
captioner(file_name)
# Out:
# [{'generated_text': 'a car with a black seat and a white stripe on it '}]

# %%
captioner2(file_name)
# Out:
# [{'generated_text': 'a white porsche car with gold rims'}]

# %%
captioner3(file_name)
# Out:
# [{'generated_text': 'car porsche 911 gt3 porsche 911 gt3 car porsche 911 gt3'}]

# %%
display(Image(filename= pic_1))
captioner2(pic_1)
# Out:
# [{'generated_text': 'a white porsche car with gold rims'}]

# %%
display(Image(filename= pic_2))
captioner2(pic_2)
# Out:
# [{'generated_text': 'jbl bluetooth speaker'}]

# %%
display(Image(filename=pic_3))
captioner2(pic_3)
# Out:
# [{'generated_text': 'the eiff tower in paris'}]
